# %% [markdown]
# <a href="https://colab.research.google.com/github/s2cretjuju/first-repository/blob/master/20251016_%EB%AF%B8%EB%8B%88_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%EC%98%81%EA%B5%AD_%EC%8B%9C%EC%9E%A5%EC%9D%98_%EC%A4%91%EA%B3%A0%EC%B0%A8_%EA%B0%80%EA%B2%A9_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%8B%A4%EB%A3%A8%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 데이터 불러오기, 살펴보기

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
car_df = pd.read_csv('cars.csv')
brand_df = pd.read_csv('brand.csv')

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history
# 0             NaN
# 1            Full
# 2             NaN
# 3            Full
# 4             NaN

# %%
brand_df.head()
# Out:
#       title         country
# 0     skoda  Czech Republic
# 1  vauxhall  United Kingdom
# 2   hyundai     South Korea
# 3      mini  United Kingdom
# 4      ford   United States

# %% [markdown]
# 2. 자동차 데이터와 브랜드 데이터 합치

# %%
# Q. car_df와 brand_df를 합치기 위해, car_df에 brand 컬럼을 추가합니다.
# title 값의 첫 번째 단어만 추출하여 brand 컬럼에 저장해주세요.

car_df['brand'] = car_df['title'].str.split().str[0].str.upper()

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     brand
# 0             NaN     SKODA
# 1            Full  VAUXHALL
# 2             NaN   HYUNDAI
# 3            Full      MINI
# 4             NaN  VAUXHALL

# %%
# Q. brand_df의 title 컬럼에 저장된 값들을 대문자로 변환합니다.

brand_df['title'] = brand_df['title'].str.upper()

# %%
brand_df.head()
# Out:
#       title         country
# 0     SKODA  Czech Republic
# 1  VAUXHALL  United Kingdom
# 2   HYUNDAI     South Korea
# 3      MINI  United Kingdom
# 4      FORD   United States

# %%
# Q. car_df의 brand 컬럼과 brand_df의 title 컬럼을 기준으로 데이터를 합칩니다.
# (힌트: car_df에서 left merge를 수행합니다.)

car_df = pd.merge(car_df, brand_df, left_on='brand', right_on='title', how='left')

# %%
car_df.head()
# Out:
#           title_x  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     brand   title_y         country
# 0             NaN     SKODA     SKODA  Czech Republic
# 1            Full  VAUXHALL  VAUXHALL  United Kingdom
# 2             NaN   HYUNDAI   HYUNDAI     South Korea
# 3            Full      MINI      MINI  United Kingdom
# 4             NaN  VAUXHALL  VAUXHALL  United Kingdom

# %%
# Q. car_df에서 중복되는 컬럼 title_y를 제거합니다.

car_df = car_df.drop('title_y', axis=1)

# %%
car_df.head()
# Out:
#           title_x  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     brand         country
# 0             NaN     SKODA  Czech Republic
# 1            Full  VAUXHALL  United Kingdom
# 2             NaN   HYUNDAI     South Korea
# 3            Full      MINI  United Kingdom
# 4             NaN  VAUXHALL  United Kingdom

# %%
# Q. car_df에서 title_x 컬럼의 이름을 title로 변경합니다.

car_df.rename(columns={'title_x': 'title'}, inplace=True)
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     brand         country
# 0             NaN     SKODA  Czech Republic
# 1            Full  VAUXHALL  United Kingdom
# 2             NaN   HYUNDAI     South Korea
# 3            Full      MINI  United Kingdom
# 4             NaN  VAUXHALL  United Kingdom

# %%
# car_df의 복사본 bonus_df를 생성합니다.

bonus_df = car_df.copy()

# %% [markdown]
# 3. 카테고리형 변수를 숫자 형태로 변환

# %%
# car_df의 컬럼 각각에 대해 자료형(data type)을 살펴봅니다.

car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3687 entries, 0 to 3686
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              3687 non-null   object
#  1   Price              3687 non-null   int64
#  2   Mileage(miles)     3687 non-null   int64
#  3   Registration_Year  3687 non-null   int64
#  4   Previous Owners    2276 non-null   float64
#  5   Fuel type          3687 non-null   object
#  6   Body type          3687 non-null   object
#  7   Engine             3642 non-null   object
#  8   Gearbox            3687 non-null   object
#  9   Doors              3662 non-null   float64
#  10  Seats              3652 non-null   float64
#  11  Emission Class     3600 non-null   object
#  12  Service history    540 non-null    object
#  13  brand              3687 non-null   object
#  14  country            3687 non-null   object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 432.2+ KB

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     brand         country
# 0             NaN     SKODA  Czech Republic
# 1            Full  VAUXHALL  United Kingdom
# 2             NaN   HYUNDAI     South Korea
# 3            Full      MINI  United Kingdom
# 4             NaN  VAUXHALL  United Kingdom

# %%
# Q. Engine 컬럼의 데이터에서 L 문자를 제거하여 숫자 부분만 저장합니다.

car_df['Engine'] = car_df['Engine'].astype(str).str.replace('L', '')

# %%
# Q. Emission Class 컬럼에서도 숫자 부분만 추출하여 저장합니다.

car_df['Emission Class'] = car_df['Emission Class'].astype(str).str.replace('Euro ', '')

# %%
# Q. to_numeric 메서드를 사용하여 Engine, Emission Class 컬럼의 자료형을 숫자 형태로 변환합니다.

car_df['Engine'] = pd.to_numeric(car_df['Engine'], errors='coerce')
car_df['Emission Class'] = pd.to_numeric(car_df['Emission Class'], errors='coerce')

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3687 entries, 0 to 3686
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              3687 non-null   object
#  1   Price              3687 non-null   int64
#  2   Mileage(miles)     3687 non-null   int64
#  3   Registration_Year  3687 non-null   int64
#  4   Previous Owners    2276 non-null   float64
#  5   Fuel type          3687 non-null   object
#  6   Body type          3687 non-null   object
#  7   Engine             3642 non-null   float64
#  8   Gearbox            3687 non-null   object
#  9   Doors              3662 non-null   float64
#  10  Seats              3652 non-null   float64
#  11  Emission Class     3600 non-null   float64
#  12  Service history    540 non-null    object
#  13  brand              3687 non-null   object
#  14  country            3687 non-null   object
# dtypes: float64(5), int64(3), object(7)
# memory usage: 432.2+ KB

# %%
car_df.describe()
# Out:
#               Price  Mileage(miles)  Registration_Year  Previous Owners  \
# count   3687.000000    3.687000e+03        3687.000000      2276.000000
# mean    5787.301058    8.132854e+04        2011.846216         2.807557
# std     4480.629885    3.941718e+04           5.082387         1.546028
# min      400.000000    1.000000e+00        1953.000000         1.000000
# 25%     2490.000000    5.698400e+04        2008.000000         2.000000
# 50%     4000.000000    8.000000e+04        2012.000000         3.000000
# 75%     7995.000000    1.030000e+05        2015.500000         4.000000
# max    33900.000000    1.110100e+06        2025.000000         9.000000
#
#             Engine        Doors        Seats  Emission Class
# count  3642.000000  3662.000000  3652.000000     3600.000000
# mean      1.606260     4.321409     4.900329        4.910000
# std       0.486584     0.986760     0.577046        0.910688
# min       0.800000     2.000000     2.000000        1.000000
# 25%       1.300000     3.000000     5.000000        4.000000
# 50%       1.600000     5.000000     5.000000        5.000000
# 75%       1.900000     5.000000     5.000000        6.000000
# max       6.300000     5.000000     7.000000        6.000000

# %% [markdown]
# 4. 결측치 제거

# %%
# car_df의 컬럼별로 결측치의 비율을 살펴봅시다.

car_df.isna().mean()
# Out:
# title                0.000000
# Price                0.000000
# Mileage(miles)       0.000000
# Registration_Year    0.000000
# Previous Owners      0.382696
# Fuel type            0.000000
# Body type            0.000000
# Engine               0.012205
# Gearbox              0.000000
# Doors                0.006781
# Seats                0.009493
# Emission Class       0.023596
# Service history      0.853539
# brand                0.000000
# country              0.000000
# dtype: float64

# %%
# Service history 컬럼에 포함된 값들을 중복 없이 보여줍니다.

car_df['Service history'].unique()
# Out:
# array([nan, 'Full'], dtype=object)

# %%
# Q. Service history 값에 따라 그룹으로 묶어 Price의 평균을 계산합니다.

car_df.groupby('Service history')['Price'].mean()
# Out:
# Service history
# Full    7290.209259
# Name: Price, dtype: float64

# %%
# Q. Service history 컬럼의 결측치를 'Unknown' 문자열로 채웁니다.

car_df['Service history'] = car_df['Service history'].fillna('Unkown')

# %%
car_df.groupby('Service history')['Price'].mean()
# Out:
# Service history
# Full      7290.209259
# Unkown    5529.414045
# Name: Price, dtype: float64

# %%
# Engine 컬럼의 결측치를 확인합니다.

car_df[car_df['Engine'].isna()]
car_df.head(10)
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
# 5   HYUNDAI COUPE    800          124196               2007              3.0
# 6      FORD FOCUS    798          140599               2008              NaN
# 7  VAUXHALL CORSA   1995           90000               2009              NaN
# 8       VOLVO 740    750          225318               2025              NaN
# 9     PEUGEOT 207   1299           87000               2008              5.0
#
#   Fuel type  Body type  Engine    Gearbox  Doors  Seats  Emission Class  \
# 0    Diesel  Hatchback     1.4     Manual    5.0    5.0             6.0
# 1    Petrol  Hatchback     1.2     Manual    3.0    5.0             4.0
# 2    Petrol  Hatchback     1.4     Manual    5.0    5.0             5.0
# 3    Petrol  Hatchback     1.4     Manual    3.0    4.0             4.0
# 4    Diesel  Hatchback     1.3     Manual    5.0    5.0             5.0
# 5    Petrol      Coupe     2.0     Manual    3.0    4.0             4.0
# 6    Petrol  Hatchback     1.6     Manual    5.0    5.0             4.0
# 7    Petrol  Hatchback     1.2     Manual    3.0    5.0             4.0
# 8    Petrol     Estate     2.3  Automatic    5.0    NaN             NaN
# 9    Diesel  Hatchback     1.6     Manual    5.0    5.0             4.0
#
#   Service history     brand         country
# 0          Unkown     SKODA  Czech Republic
# 1            Full  VAUXHALL  United Kingdom
# 2          Unkown   HYUNDAI     South Korea
# 3            Full      MINI  United Kingdom
# 4          Unkown  VAUXHALL  United Kingdom
# 5          Unkown   HYUNDAI     South Korea
# 6          Unkown      FORD   United States
# 7          Unkown  VAUXHALL  United Kingdom
# 8          Unkown     VOLVO          Sweden
# 9          Unkown   PEUGEOT          France

# %%
# 결측치가 포함된 컬럼의 개수를 데이터마다 계산하여 na_values 컬럼에 저장합니다.

car_df['na_values'] = car_df.isna().sum(axis = 1)

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 0    Diesel  Hatchback     1.4  Manual    5.0    5.0             6.0
# 1    Petrol  Hatchback     1.2  Manual    3.0    5.0             4.0
# 2    Petrol  Hatchback     1.4  Manual    5.0    5.0             5.0
# 3    Petrol  Hatchback     1.4  Manual    3.0    4.0             4.0
# 4    Diesel  Hatchback     1.3  Manual    5.0    5.0             5.0
#
#   Service history     brand         country  na_values
# 0          Unkown     SKODA  Czech Republic          0
# 1            Full  VAUXHALL  United Kingdom          0
# 2          Unkown   HYUNDAI     South Korea          1
# 3            Full      MINI  United Kingdom          0
# 4          Unkown  VAUXHALL  United Kingdom          1

# %%
# na_values 컬럼의 값이 4 이상인 행이 몇 개인지 확인

len(car_df[car_df['na_values'] >= 4])
# Out:
# 13

# %%
# Q. na_values 컬럼의 값이 4 이상인 데이터는 제거합니다.

car_df = car_df[car_df['na_values'] < 4]

# %%
# na_values 컬럼을 제거합니다.

car_df.drop('na_values', axis = 1, inplace = True)

# %%
car_df.isna().mean()
# Out:
# title                0.000000
# Price                0.000000
# Mileage(miles)       0.000000
# Registration_Year    0.000000
# Previous Owners      0.382961
# Fuel type            0.000000
# Body type            0.000000
# Engine               0.009526
# Gearbox              0.000000
# Doors                0.003266
# Seats                0.005988
# Emission Class       0.020142
# Service history      0.000000
# brand                0.000000
# country              0.000000
# dtype: float64

# %% [markdown]
# 다른 컬럼들의 결측치를 채우기 위해, 히스토그램을 그리고 중앙값을 계산

# %%
# Previous Owners 컬럼의 히스토그램을 그립니다.

sns.displot(car_df['Previous Owners'])

# %%
# Previous Owners 컬럼의 중앙값을 계산합니다.

car_df['Previous Owners'].median()
# Out:
# 3.0

# %%
sns.displot(car_df['Engine'])

# %%
car_df['Engine'].mean()
# Out:
# np.float64(1.6061555372355043)

# %%
car_df['Engine'].median()
# Out:
# 1.6

# %%
sns.displot(car_df['Doors'])

# %%
car_df['Doors'].median()
# Out:
# 5.0

# %%
sns.displot(car_df['Seats'])

# %%
sns.displot(car_df['Emission Class'])

# %%
# Q. 해당 컬럼들의 중앙값으로 결측치를 채웁니다.

car_df['Previous Owners'] = car_df['Previous Owners'].fillna(car_df['Previous Owners'].median())
car_df['Engine'] = car_df['Engine'].fillna(car_df['Engine'].median())
car_df['Doors'] = car_df['Doors'].fillna(car_df['Doors'].median())
car_df['Seats'] = car_df['Seats'].fillna(car_df['Seats'].median())
car_df['Emission Class'] = car_df['Emission Class'].fillna(car_df['Emission Class'].median())
car_df
# Out:
#                title  Price  Mileage(miles)  Registration_Year  \
# 0        SKODA FABIA   6900           70189               2016
# 1     VAUXHALL CORSA   1495           88585               2008
# 2        HYUNDAI I30    949          137000               2011
# 3         MINI HATCH   2395           96731               2010
# 4     VAUXHALL CORSA   1000           85000               2013
# ...              ...    ...             ...                ...
# 3682  RENAULT MEGANE   1395           76202               2006
# 3683         AUDI A4   6990          119000               2012
# 3684    BMW 3 SERIES   3995          139000               2013
# 3685    HONDA ACCORD   1390          179190               2007
# 3686  VAUXHALL CORSA   2000           82160               2013
#
#       Previous Owners Fuel type  Body type  Engine Gearbox  Doors  Seats  \
# 0                 3.0    Diesel  Hatchback     1.4  Manual    5.0    5.0
# 1                 4.0    Petrol  Hatchback     1.2  Manual    3.0    5.0
# 2                 3.0    Petrol  Hatchback     1.4  Manual    5.0    5.0
# 3                 5.0    Petrol  Hatchback     1.4  Manual    3.0    4.0
# 4                 3.0    Diesel  Hatchback     1.3  Manual    5.0    5.0
# ...               ...       ...        ...     ...     ...    ...    ...
# 3682              4.0    Petrol  Hatchback     1.6  Manual    5.0    5.0
# 3683              3.0    Petrol     Saloon     2.0  Manual    4.0    5.0
# 3684              3.0    Diesel     Saloon     2.0  Manual    4.0    5.0
# 3685              3.0    Diesel     Estate     2.2  Manual    5.0    5.0
# 3686              7.0    Petrol  Hatchback     1.2  Manual    5.0    5.0
#
#       Emission Class Service history     brand         country
# 0                6.0          Unkown     SKODA  Czech Republic
# 1                4.0            Full  VAUXHALL  United Kingdom
# 2                5.0          Unkown   HYUNDAI     South Korea
# 3                4.0            Full      MINI  United Kingdom
# 4                5.0          Unkown  VAUXHALL  United Kingdom
# ...              ...             ...       ...             ...
# 3682             4.0          Unkown   RENAULT          France
# 3683             5.0          Unkown      AUDI         Germany
# 3684             5.0          Unkown       BMW         Germany
# 3685             4.0            Full     HONDA           Japan
# 3686             5.0          Unkown  VAUXHALL  United Kingdom
#
# [3674 rows x 15 columns]

# %% [markdown]
# 5. 이상치 제거

# %%
# car_df 통계 확인
car_df.describe()
# Out:
#               Price  Mileage(miles)  Registration_Year  Previous Owners  \
# count   3674.000000    3.674000e+03        3674.000000      3674.000000
# mean    5788.852477    8.134587e+04        2011.847305         2.882145
# std     4486.599984    3.943769e+04           5.083173         1.219004
# min      400.000000    1.000000e+00        1953.000000         1.000000
# 25%     2490.000000    5.698400e+04        2008.000000         2.000000
# 50%     4000.000000    8.000000e+04        2012.000000         3.000000
# 75%     7995.000000    1.030000e+05        2016.000000         3.000000
# max    33900.000000    1.110100e+06        2025.000000         9.000000
#
#             Engine        Doors        Seats  Emission Class
# count  3674.000000  3674.000000  3674.000000     3674.000000
# mean      1.606097     4.323625     4.900925        4.911813
# std       0.484326     0.985908     0.575367        0.901556
# min       0.800000     2.000000     2.000000        1.000000
# 25%       1.300000     3.000000     5.000000        4.000000
# 50%       1.600000     5.000000     5.000000        5.000000
# 75%       1.900000     5.000000     5.000000        6.000000
# max       6.300000     5.000000     7.000000        6.000000

# %%
# Price 컬럼의 값들을 정렬하여 보여줍니다.

car_df['Price'].sort_values()
# Out:
# 3245      400
# 3278      450
# 1238      495
# 3246      499
# 3242      500
#         ...
# 3230    25995
# 3102    25995
# 3224    28240
# 2936    30000
# 3212    33900
# Name: Price, Length: 3674, dtype: int64

# %%
# Mileage(miles) 컬럼의 값들을 정렬하여 보여줍니다.

car_df['Mileage(miles)'].sort_values()
# Out:
# 3100          1
# 3219          1
# 2013          6
# 3102        222
# 2760       1048
#          ...
# 1478     274100
# 1685     274100
# 1946     274100
# 2048     274100
# 1037    1110100
# Name: Mileage(miles), Length: 3674, dtype: int64

# %%
# Mileage 값이 1000 미만인 데이터

car_df[car_df['Mileage(miles)'] < 1000]
# Out:
#            title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 2013       MG ZT  15500               6               2004              4.0
# 3100    MG MG ZS  18365               1               2023              3.0
# 3102  SEAT ATECA  25995             222               2023              3.0
# 3219    MG MG ZS  18515               1               2023              3.0
#
#      Fuel type Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 2013    Petrol    Saloon     1.8  Manual    4.0    5.0             3.0
# 3100    Petrol       SUV     1.5  Manual    5.0    5.0             6.0
# 3102    Petrol       SUV     1.5  Manual    5.0    5.0             6.0
# 3219    Petrol       SUV     1.5  Manual    5.0    5.0             6.0
#
#      Service history brand         country
# 2013          Unkown    MG  United Kingdom
# 3100          Unkown    MG  United Kingdom
# 3102          Unkown  SEAT           Spain
# 3219          Unkown    MG  United Kingdom

# %%
# Q. Mileage(miles) 컬럼의 값이 1000 이하인 데이터를 제거합니다.

car_df = car_df[car_df['Mileage(miles)'] > 1000]

# %%
car_df['Registration_Year'].sort_values()
# Out:
# 3024    1953
# 237     1972
# 2375    1981
# 1239    1985
# 1195    1987
#         ...
# 2080    2022
# 2760    2023
# 2967    2023
# 3173    2023
# 8       2025
# Name: Registration_Year, Length: 3670, dtype: int64

# %%
# Registration_Year 컬럼의 값이 2025 미만인 데이터만 추출합니다.

car_df = car_df[car_df['Registration_Year'] < 2025]

# %%
car_df['Previous Owners'].sort_values()
# Out:
# 3321    1.0
# 3304    1.0
# 2534    1.0
# 2533    1.0
# 2530    1.0
#        ...
# 1314    9.0
# 3463    9.0
# 404     9.0
# 212     9.0
# 3331    9.0
# Name: Previous Owners, Length: 3669, dtype: float64

# %%
car_df[car_df['Previous Owners'] == 9]
# Out:
#                title  Price  Mileage(miles)  Registration_Year  \
# 212   VAUXHALL CORSA   1500           96270               2008
# 404     BMW 3 SERIES   2500          138910               2003
# 1314      MINI HATCH   1875           98710               2007
# 3331  PEUGEOT 207 SW    895          114312               2008
# 3463  PEUGEOT 207 SW   1450          115000               2009
#
#       Previous Owners Fuel type    Body type  Engine Gearbox  Doors  Seats  \
# 212               9.0    Petrol    Hatchback     1.4  Manual    5.0    5.0
# 404               9.0    Petrol  Convertible     2.5  Manual    2.0    4.0
# 1314              9.0    Petrol    Hatchback     1.6  Manual    3.0    4.0
# 3331              9.0    Petrol       Estate     1.4  Manual    5.0    5.0
# 3463              9.0    Petrol       Estate     1.4  Manual    5.0    5.0
#
#       Emission Class Service history     brand         country
# 212              4.0          Unkown  VAUXHALL  United Kingdom
# 404              3.0          Unkown       BMW         Germany
# 1314             4.0          Unkown      MINI  United Kingdom
# 3331             4.0          Unkown   PEUGEOT          France
# 3463             4.0          Unkown   PEUGEOT          France

# %%
# Q. brand 컬럼의 값에 따라 데이터를 그룹화하여 Price의 평균, 표준편차를 계산합니다.
# (agg() 함수를 사용해주세요.)

car_df.groupby('brand')['Price'].agg(['mean', 'std'])
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              3.0
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              3.0
#
#   Fuel type  Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 0    Diesel  Hatchback     1.4  Manual    5.0    5.0             6.0
# 1    Petrol  Hatchback     1.2  Manual    3.0    5.0             4.0
# 2    Petrol  Hatchback     1.4  Manual    5.0    5.0             5.0
# 3    Petrol  Hatchback     1.4  Manual    3.0    4.0             4.0
# 4    Diesel  Hatchback     1.3  Manual    5.0    5.0             5.0
#
#   Service history     brand         country
# 0          Unkown     SKODA  Czech Republic
# 1            Full  VAUXHALL  United Kingdom
# 2          Unkown   HYUNDAI     South Korea
# 3            Full      MINI  United Kingdom
# 4          Unkown  VAUXHALL  United Kingdom

# %%
# Q. brand와 Fuel type 컬럼을 기준으로 Price 값의 피벗 테이블을 생성합니다.

pd.pivot_table(car_df, index='brand', columns='Fuel type', values='Price')
# Out:
# Fuel type            Diesel  Diesel Hybrid  Electric        Petrol  \
# brand
# ABARTH                  NaN            NaN       NaN  11216.333333
# ALFA            4214.666667            NaN       NaN   2688.750000
# AUDI            8731.301205            NaN       NaN   6386.555556
# BMW             7342.022222        23220.0       NaN   7058.486239
# CHEVROLET       5249.500000            NaN       NaN   3012.000000
# CHRYSLER                NaN            NaN       NaN   2433.800000
# CITROEN         4026.891892            NaN       NaN   5052.206897
# DACIA           6754.600000            NaN       NaN   7820.111111
# DAEWOO                  NaN            NaN       NaN    995.000000
# DAIHATSU                NaN            NaN       NaN   1695.000000
# DODGE                   NaN            NaN       NaN   3250.000000
# DS             14025.000000            NaN       NaN  10981.000000
# FIAT            5036.777778            NaN       NaN   4027.138298
# FORD            5567.482759            NaN       NaN   4578.709898
# HONDA           6361.321429            NaN       NaN   2884.120000
# HYUNDAI         5815.222222            NaN       NaN   4440.534247
# INFINITI        8582.000000            NaN       NaN   8888.000000
# ISUZU           2250.000000            NaN       NaN           NaN
# JAGUAR          8717.807692            NaN       NaN   8440.000000
# JEEP            1915.833333            NaN       NaN   5016.666667
# KIA             7103.000000            NaN       NaN   7858.075472
# LAGONDA                 NaN            NaN       NaN  14995.000000
# LAND           11336.833333            NaN       NaN   7169.000000
# LEXUS                   NaN            NaN       NaN   4209.857143
# MARCOS                  NaN            NaN       NaN  11495.000000
# MASERATI       13900.000000            NaN       NaN  13000.000000
# MAZDA           6725.000000            NaN   13899.0   4952.951220
# MERCEDES-BENZ   7243.145833            NaN       NaN   8316.236111
# MG                      NaN            NaN       NaN   5622.285714
# MINI            6334.785714            NaN       NaN   6504.698795
# MITSUBISHI      2440.761905            NaN       NaN   4247.181818
# NISSAN          6679.380000            NaN    5390.0   6787.444444
# PEUGEOT         6438.769841            NaN       NaN   4431.798319
# PORSCHE         8105.000000            NaN       NaN   4125.000000
# PROTON                  NaN            NaN       NaN   2226.666667
# RENAULT         4312.788462            NaN       NaN   6177.439024
# ROVER                   NaN            NaN       NaN   2382.800000
# SAAB                    NaN            NaN       NaN   2983.428571
# SEAT            5917.000000            NaN       NaN   4046.954545
# SKODA           5364.900000            NaN       NaN   5925.652174
# SMART           5400.000000            NaN       NaN   5695.000000
# SSANGYONG       8636.000000            NaN       NaN           NaN
# SUBARU          4990.000000            NaN       NaN   3215.000000
# SUZUKI          6886.000000            NaN       NaN   3507.451613
# TOYOTA          3180.920000            NaN       NaN   4368.142857
# VAUXHALL        4341.878505            NaN   13998.0   4702.904545
# VOLKSWAGEN      5466.855556            NaN       NaN   6985.865922
# VOLVO           4465.045455            NaN       NaN   2836.764706
#
# Fuel type      Petrol Hybrid  Petrol Plug-in Hybrid
# brand
# ABARTH                   NaN                    NaN
# ALFA                     NaN                    NaN
# AUDI                     NaN                    NaN
# BMW                      NaN           19460.652174
# CHEVROLET                NaN                    NaN
# CHRYSLER                 NaN                    NaN
# CITROEN                  NaN                    NaN
# DACIA                    NaN                    NaN
# DAEWOO                   NaN                    NaN
# DAIHATSU                 NaN                    NaN
# DODGE                    NaN                    NaN
# DS                       NaN           24770.000000
# FIAT                     NaN                    NaN
# FORD                     NaN                    NaN
# HONDA                 4749.0                    NaN
# HYUNDAI              17949.5                    NaN
# INFINITI                 NaN                    NaN
# ISUZU                    NaN                    NaN
# JAGUAR                   NaN                    NaN
# JEEP                     NaN                    NaN
# KIA                  18750.0                    NaN
# LAGONDA                  NaN                    NaN
# LAND                     NaN                    NaN
# LEXUS                 4225.0                    NaN
# MARCOS                   NaN                    NaN
# MASERATI                 NaN                    NaN
# MAZDA                    NaN                    NaN
# MERCEDES-BENZ            NaN                    NaN
# MG                       NaN                    NaN
# MINI                     NaN                    NaN
# MITSUBISHI               NaN                    NaN
# NISSAN                   NaN                    NaN
# PEUGEOT                  NaN                    NaN
# PORSCHE                  NaN                    NaN
# PROTON                   NaN                    NaN
# RENAULT                  NaN                    NaN
# ROVER                    NaN                    NaN
# SAAB                     NaN                    NaN
# SEAT                     NaN                    NaN
# SKODA                    NaN                    NaN
# SMART                    NaN                    NaN
# SSANGYONG                NaN                    NaN
# SUBARU                   NaN                    NaN
# SUZUKI               10706.0                    NaN
# TOYOTA               11731.0                    NaN
# VAUXHALL                 NaN            9499.000000
# VOLKSWAGEN               NaN           11297.500000
# VOLVO                    NaN                    NaN

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              3.0
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              3.0
#
#   Fuel type  Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 0    Diesel  Hatchback     1.4  Manual    5.0    5.0             6.0
# 1    Petrol  Hatchback     1.2  Manual    3.0    5.0             4.0
# 2    Petrol  Hatchback     1.4  Manual    5.0    5.0             5.0
# 3    Petrol  Hatchback     1.4  Manual    3.0    4.0             4.0
# 4    Diesel  Hatchback     1.3  Manual    5.0    5.0             5.0
#
#   Service history     brand         country
# 0          Unkown     SKODA  Czech Republic
# 1            Full  VAUXHALL  United Kingdom
# 2          Unkown   HYUNDAI     South Korea
# 3            Full      MINI  United Kingdom
# 4          Unkown  VAUXHALL  United Kingdom

# %%
# Previous Owners와 Price 사이의 scatter plot을 그립니다.

sns.scatterplot( x= car_df['Previous Owners'], y = car_df['Price'])
# Out:
# <Axes: xlabel='Previous Owners', ylabel='Price'>

# %%
# Registration_Year와 Price 사이의 scatter plot을 그립니다.

sns.scatterplot( x= car_df['Registration_Year'], y = car_df['Price'])
# Out:
# <Axes: xlabel='Registration_Year', ylabel='Price'>

# %%
sns.scatterplot( x= car_df['Registration_Year'], y = np.log(car_df['Price']))
# Out:
# <Axes: xlabel='Registration_Year', ylabel='Price'>

# %% [markdown]
# 6. scaler 이용

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              3.0
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              3.0
#
#   Fuel type  Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 0    Diesel  Hatchback     1.4  Manual    5.0    5.0             6.0
# 1    Petrol  Hatchback     1.2  Manual    3.0    5.0             4.0
# 2    Petrol  Hatchback     1.4  Manual    5.0    5.0             5.0
# 3    Petrol  Hatchback     1.4  Manual    3.0    4.0             4.0
# 4    Diesel  Hatchback     1.3  Manual    5.0    5.0             5.0
#
#   Service history     brand         country
# 0          Unkown     SKODA  Czech Republic
# 1            Full  VAUXHALL  United Kingdom
# 2          Unkown   HYUNDAI     South Korea
# 3            Full      MINI  United Kingdom
# 4          Unkown  VAUXHALL  United Kingdom

# %%
# 특정 컬럼들이 몇 종류의 데이터로 이루어져 있는지 계산합니다.

car_df[['title','Fuel type','Body type','Gearbox','Emission Class','Service history','brand','country']].nunique()
# Out:
# title              448
# Fuel type            6
# Body type           10
# Gearbox              2
# Emission Class       6
# Service history      2
# brand               48
# country             12
# dtype: int64

# %%
car_df.drop('title', axis = 1, inplace = True)

# %%
# 자동차의 브랜드별로 데이터의 개수를 계산합니다.

car_df['brand'].value_counts()
# Out:
# brand
# VAUXHALL         549
# FORD             409
# VOLKSWAGEN       271
# BMW              268
# PEUGEOT          245
# TOYOTA           193
# NISSAN           178
# RENAULT          175
# MERCEDES-BENZ    168
# AUDI             146
# HONDA            108
# FIAT             103
# MINI              97
# CITROEN           95
# HYUNDAI           93
# KIA               82
# SKODA             63
# SEAT              59
# MAZDA             53
# SUZUKI            41
# VOLVO             39
# LAND              35
# MITSUBISHI        32
# JAGUAR            30
# ALFA              18
# DACIA             14
# CHEVROLET         14
# SUBARU            11
# JEEP               9
# LEXUS              9
# MG                 7
# SAAB               7
# INFINITI           7
# DS                 6
# ROVER              5
# CHRYSLER           5
# SMART              4
# PROTON             3
# ABARTH             3
# PORSCHE            3
# MASERATI           3
# DAIHATSU           2
# SSANGYONG          2
# DODGE              1
# DAEWOO             1
# MARCOS             1
# LAGONDA            1
# ISUZU              1
# Name: count, dtype: int64

# %%
# 자동차의 브랜드별로 평균 가격을 계산합니다.

car_df.groupby('brand')['Price'].mean()
# Out:
# brand
# ABARTH           11216.333333
# ALFA              3197.388889
# AUDI              7719.527397
# BMW               8325.981343
# CHEVROLET         3331.642857
# CHRYSLER          2433.800000
# CITROEN           4652.873684
# DACIA             7439.571429
# DAEWOO             995.000000
# DAIHATSU          1695.000000
# DODGE             3250.000000
# DS               14293.833333
# FIAT              4115.359223
# FORD              4859.144254
# HONDA             3871.953704
# HYUNDAI           4997.118280
# INFINITI          8625.714286
# ISUZU             2250.000000
# JAGUAR            8680.766667
# JEEP              2949.444444
# KIA               7733.073171
# LAGONDA          14995.000000
# LAND             10741.428571
# LEXUS             4213.222222
# MARCOS           11495.000000
# MASERATI         13300.000000
# MAZDA             5489.528302
# MERCEDES-BENZ     7703.041667
# MG                5622.285714
# MINI              6480.175258
# MITSUBISHI        3061.718750
# NISSAN            6529.415730
# PEUGEOT           5463.955102
# PORSCHE           5451.666667
# PROTON            2226.666667
# RENAULT           5623.371429
# ROVER             2382.800000
# SAAB              2983.428571
# SEAT              4522.389831
# SKODA             5569.619048
# SMART             5621.250000
# SSANGYONG         8636.000000
# SUBARU            3376.363636
# SUZUKI            5076.853659
# TOYOTA            5282.544041
# VAUXHALL          4658.207650
# VOLKSWAGEN        6513.217712
# VOLVO             3755.282051
# Name: Price, dtype: float64

# %%
# Q. 자동차의 브랜드별로 데이터 개수와 평균 가격을 출력합니다.
# (위에서 출력했던 데이터 두 가지를 join 메서드로 합쳐주세요.)

car_df.groupby('brand')['Price'].agg(['mean', 'count'])
# Out:
#                        mean  count
# brand
# ABARTH         11216.333333      3
# ALFA            3197.388889     18
# AUDI            7719.527397    146
# BMW             8325.981343    268
# CHEVROLET       3331.642857     14
# CHRYSLER        2433.800000      5
# CITROEN         4652.873684     95
# DACIA           7439.571429     14
# DAEWOO           995.000000      1
# DAIHATSU        1695.000000      2
# DODGE           3250.000000      1
# DS             14293.833333      6
# FIAT            4115.359223    103
# FORD            4859.144254    409
# HONDA           3871.953704    108
# HYUNDAI         4997.118280     93
# INFINITI        8625.714286      7
# ISUZU           2250.000000      1
# JAGUAR          8680.766667     30
# JEEP            2949.444444      9
# KIA             7733.073171     82
# LAGONDA        14995.000000      1
# LAND           10741.428571     35
# LEXUS           4213.222222      9
# MARCOS         11495.000000      1
# MASERATI       13300.000000      3
# MAZDA           5489.528302     53
# MERCEDES-BENZ   7703.041667    168
# MG              5622.285714      7
# MINI            6480.175258     97
# MITSUBISHI      3061.718750     32
# NISSAN          6529.415730    178
# PEUGEOT         5463.955102    245
# PORSCHE         5451.666667      3
# PROTON          2226.666667      3
# RENAULT         5623.371429    175
# ROVER           2382.800000      5
# SAAB            2983.428571      7
# SEAT            4522.389831     59
# SKODA           5569.619048     63
# SMART           5621.250000      4
# SSANGYONG       8636.000000      2
# SUBARU          3376.363636     11
# SUZUKI          5076.853659     41
# TOYOTA          5282.544041    193
# VAUXHALL        4658.207650    549
# VOLKSWAGEN      6513.217712    271
# VOLVO           3755.282051     39

# %%
car_df = pd.get_dummies(car_df, drop_first = True)

# %%
from sklearn.preprocessing import RobustScaler

# %%
# Q. Robust Scaler를 rs 변수로 정의해줍니다.

rs = RobustScaler()

# %%
# Q. robust scaling을 적용한 데이터프레임을 car_df 변수에 다시 저장합니다.

car_df = pd.DataFrame(rs.fit_transform(car_df), columns = car_df.columns)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
# Q. 주성분이 5개인 PCA 모델을 정의합니다.

# pca = PCA(5)

# %%
# Q. car_df 데이터에 PCA를 적용합니다.

# pca.fit(car_df)

# %%
# Q. 원본 데이터 대비 PCA 데이터의 분산(explained variance) 비율을 계산합니다.

# pca.explained_varience_ratio_.sum()

# %%
# 주성분의 개수가 2~10개일 때 explained variance ratio를 각각 계산합니다.

for i in range(2, 11):
    pca = PCA(i)
    pca.fit(car_df)
    print(i, round(pca.explained_variance_ratio_.sum(), 2))
# Out:
# 2 0.41
# 3 0.52
# 4 0.59
# 5 0.64
# 6 0.68
# 7 0.71
# 8 0.74
# 9 0.77
# 10 0.79

# %%
pca = PCA(7)

# %%
# Q. 주성분 개수가 7개일 때, PC1~PC7 컬럼을 출력합니다.

pd.DataFrame(pca.fit_transform(car_df), columns = ['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7'])
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7
# 0    -0.514980 -0.422637  0.415003  0.646676  0.287282  0.032610  0.017744
# 1     1.312384 -1.217170 -0.349554 -0.268356 -0.159763  0.998415 -0.070193
# 2     0.812080 -0.223882 -1.006030  0.654407  0.663232  0.051149 -0.084697
# 3     1.961983 -1.312642  0.517619 -0.709751  0.546531  0.644088 -0.133217
# 4     0.267575 -0.653314 -0.514638  0.555964 -0.125742  1.161923 -0.179273
# ...        ...       ...       ...       ...       ...       ...       ...
# 3664  1.427772 -0.807223 -0.187850  0.093612 -0.565527 -0.429525  0.001001
# 3665  0.435272  1.081559  0.283845 -0.141185  0.549215 -0.033513  0.091047
# 3666  0.757281  1.455642  0.085260  0.230943  0.864446  0.084921 -0.061957
# 3667  1.658730  1.682128 -1.001384  0.811344  0.409602 -0.056047 -0.769035
# 3668  2.919977 -2.386255  1.901952  0.806527  0.060973  1.044695 -0.021812
#
# [3669 rows x 7 columns]

# %%
# Q. 국가별로 브랜드의 개수를 계산해봅시다.
# (이전에 복사해둔 bonus_df를 사용합니다.)

bonus_df.groupby('country')['brand'].nunique()
# Out:
# country
# Czech Republic     1
# France             4
# Germany            6
# Italy              4
# Japan             11
# Malaysia           1
# Romania            1
# South Korea        4
# Spain              1
# Sweden             2
# United Kingdom     8
# United States      5
# Name: brand, dtype: int64

# %%
# Q. bonus_df의 각 컬럼들에 대해 상관 계수를 출력합니다.

# Select only numeric columns before calculating correlation
numeric_bonus_df = bonus_df.select_dtypes(include=['number'])
display(numeric_bonus_df.corr())

#  ValueError: could not convert string to float: 'SKODA FABIA' 오류 수정과 상관 계수 출력
# Out:
#                       Price  Mileage(miles)  Registration_Year  \
# Price              1.000000       -0.500358           0.722971
# Mileage(miles)    -0.500358        1.000000          -0.410781
# Registration_Year  0.722971       -0.410781           1.000000
# Previous Owners   -0.479424        0.316160          -0.501045
# Doors              0.113335       -0.037024           0.219365
# Seats             -0.027393        0.095271           0.037166
#
#                    Previous Owners     Doors     Seats
# Price                    -0.479424  0.113335 -0.027393
# Mileage(miles)            0.316160 -0.037024  0.095271
# Registration_Year        -0.501045  0.219365  0.037166
# Previous Owners           1.000000 -0.153262 -0.029338
# Doors                    -0.153262  1.000000  0.497160
# Seats                    -0.029338  0.497160  1.000000
